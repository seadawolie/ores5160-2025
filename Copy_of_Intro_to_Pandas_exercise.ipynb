# %% [markdown]
# <a href="https://colab.research.google.com/github/seadawolie/ores5160-2025/blob/main/Copy_of_Intro_to_Pandas_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Here is the data for this esercise:**
# Download the following file and upload it using the code block above. Then rename the long file name to airquality.csv.
#
# https://drive.google.com/file/d/1SBD8R6jl5_ycl3X7hulrlHpqR-w3i__a/view?usp=drive_link
#
# The information below is for licensing compliance purposes per dataset owner instructions.
#
# License: https://creativecommons.org/licenses/by-sa/4.0/.
# Data Source: https://openaq.org/#/about.
# Changes: Subset by country US and limited to the most recent week of data in the dataset
# The interactive tables feature only supports 20,000 rows, and this file has a lot more than that, so we are going to read it in and tell Pandas to only look at the first 10,000 rows. When we are just getting a sense for the type of data in the file, this is fine. Later if we need to read all of the data, we can simply remove the nrows= flag from the code.

# %% [markdown]
# Instructions
#
#
# *   Use Google Colab or your preferred Python environment.
# *   Upload the dataset(s) as instructed in each question.

# %% [markdown]
# Q1. Upload and Preview Data
#
# 	1.	Upload the file airquality.csv to your Colab environment.\\
#
# 	2.	Load the first 10,000 rows into a Pandas dataframe called airquality.\\
#
# 	3.	Display the first 5 rows of the dataframe.\\

# %%
import os

# Rename the uploaded file to 'airquality.csv'
os.rename('us_air_quality_one_week_2022_06_23 (1).xlsx', 'airquality.csv')

print("File 'us_air_quality_one_week_2022_06_23 (1).xlsx' renamed to 'airquality.csv'.")
print(os.listdir('.'))
# Out:
# File 'us_air_quality_one_week_2022_06_23 (1).xlsx' renamed to 'airquality.csv'.
# ['.config', 'airquality.csv', 'sample_data']

# %% [markdown]
# Once this cell is run, you can then execute cell `CtSAASRrS9iu` to load the data.

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'us_air_quality_one_week_2022_06_23 (1).xlsx', 'sample_data']

# %%
import pandas as pd

# 1. Upload the file airquality.csv to your Colab environment.
# (This step is typically done manually or using files.upload() if not already present).

# 2. Load the first 10,000 rows into a Pandas dataframe called airquality.
try:
    airquality = pd.read_excel('airquality.csv', nrows=10000) # Changed from pd.read_csv to pd.read_excel

    # 3. Display the first 5 rows of the dataframe.
    print(airquality.head())
except FileNotFoundError:
    print("Error: 'airquality.csv' not found. Please upload the file to your Colab environment first.")
# Out:
#                location                           city country pollutant  \
# 0  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 1  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 2  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 3  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
# 4  MILWAUKEE COLLEGE AV  Milwaukee-Waukesha-West Allis      US        bc
#
#    value   unit source_name  latitude  longitude  averaged_over_in_hours  \
# 0   0.33  碌g/m鲁      AirNow         1   42.93257               -87.93434
# 1   1.68  碌g/m鲁      AirNow         1   42.93257               -87.93434
# 2   0.63  碌g/m鲁      AirNow         1   42.93257               -87.93434
# 3   1.86  碌g/m鲁      AirNow         1   42.93257               -87.93434
# 4   0.33  碌g/m鲁      AirNow         1   42.93257               -87.93434
#
#        location_geom       date      time
# 0  POINT(42.93257 1) 2022-05-26  05:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-19e1343e-e22b-4ed4-ba24-d01776a0accd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19e1343e-e22b-4ed4-ba24-d01776a0accd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Once the file is uploaded, you can run the cell containing the `pd.read_csv` command again to load the data.

# %% [markdown]
# Q2. Data Summary and Cleaning
#
# 	1.	Use .info() and .describe(include="all") to explore the dataset.\\
#
# 	2.	Identify any columns that have missing (NaN) values.\\
#
# 	3.	Drop all rows that contain missing values.\\

# %%
# 1. Use .info() and .describe(include="all") to explore the dataset.
print("DataFrame Info:")
airquality.info()

print("\nDataFrame Descriptive Statistics (including all columns):")
display(airquality.describe(include="all"))
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   location                10000 non-null  object
#  1   city                    10000 non-null  object
#  2   country                 10000 non-null  object
#  3   pollutant               10000 non-null  object
#  4   value                   10000 non-null  float64
#  5   unit                    10000 non-null  object
#  6   source_name             10000 non-null  object
#  7   latitude                10000 non-null  int64
#  8   longitude               10000 non-null  float64
#  9   averaged_over_in_hours  10000 non-null  float64
#  10  location_geom           10000 non-null  object
#  11  date                    10000 non-null  datetime64[ns]
#  12  time                    10000 non-null  object
# ...

# %%
# 2. Identify any columns that have missing (NaN) values.
print("\nMissing values per column:")
missing_values = airquality.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Missing values per column:
# Series([], dtype: int64)

# %%
import os

file_path = 'us_air_quality_one_week_2022_06_23 (1).xlsx'
if os.path.exists(file_path):
    print(f"The file '{file_path}' exists at: {os.path.abspath(file_path)}")
else:
    print(f"The file '{file_path}' does not exist in the current directory.")
print("Current directory contents:")
print(os.listdir('.'))
# Out:
# The file 'us_air_quality_one_week_2022_06_23 (1).xlsx' exists at: /content/us_air_quality_one_week_2022_06_23 (1).xlsx
# Current directory contents:
# ['.config', 'us_air_quality_one_week_2022_06_23 (1).xlsx', 'sample_data']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for pm25 pollutant
pm25_data = airquality[airquality['pollutant'] == 'pm25']

if not pm25_data.empty:
    # 1. Create a histogram of the pm25 values.
    plt.figure(figsize=(10, 6))
    sns.histplot(pm25_data['value'], kde=True, bins=30)
    plt.title('Histogram of pm25 Values')
    plt.xlabel('pm25 Value')
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.show()

    # 2. Create a boxplot for the pm25 column.
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=pm25_data['value'])
    plt.title('Boxplot of pm25 Values')
    plt.ylabel('pm25 Value')
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("No 'pm25' data found in the dataset. Available pollutants are:")
    print(airquality['pollutant'].unique())
# Out:
# No 'pm25' data found in the dataset. Available pollutants are:
# ['bc' 'co']

# %%
# 3. Drop all rows that contain missing values.
initial_rows = airquality.shape[0]
airquality.dropna(inplace=True)
final_rows = airquality.shape[0]
print(f"\nDropped {initial_rows - final_rows} rows with missing values.")
print("Shape of DataFrame after dropping missing values:", airquality.shape)
# Out:
# Dropped 0 rows with missing values.
# Shape of DataFrame after dropping missing values: (10000, 13)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for 'co' pollutant (assuming co_data is already defined from previous step)
# If co_data is not defined, uncomment the line below:
# co_data = airquality[airquality['pollutant'] == 'co']

if not co_data.empty:
    # Create a histogram of the 'co' values.
    plt.figure(figsize=(10, 6))
    sns.histplot(co_data['value'], kde=True, bins=30)
    plt.title('Histogram of Carbon Monoxide (co) Values')
    plt.xlabel('co Value')
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("No 'co' data found in the dataset.")

# %%
print(airquality['pollutant'].unique())
# Out:
# ['bc' 'co']

# %% [markdown]
# ### Q2. Data Summary and Cleaning

# %%
# 1. Use .info() and .describe(include="all") to explore the dataset.
print("DataFrame Info:")
airquality.info()

print("\nDataFrame Descriptive Statistics (including all columns):")
display(airquality.describe(include="all"))
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   location                10000 non-null  object
#  1   city                    10000 non-null  object
#  2   country                 10000 non-null  object
#  3   pollutant               10000 non-null  object
#  4   value                   10000 non-null  float64
#  5   unit                    10000 non-null  object
#  6   source_name             10000 non-null  object
#  7   latitude                10000 non-null  int64
#  8   longitude               10000 non-null  float64
#  9   averaged_over_in_hours  10000 non-null  float64
#  10  location_geom           10000 non-null  object
#  11  date                    10000 non-null  datetime64[ns]
#  12  time                    10000 non-null  object
# ...

# %%
# 2. Identify any columns that have missing (NaN) values.
print("\nMissing values per column:")
missing_values = airquality.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Missing values per column:
# Series([], dtype: int64)

# %%
# 3. Drop all rows that contain missing values.
initial_rows = airquality.shape[0]
airquality.dropna(inplace=True)
final_rows = airquality.shape[0]
print(f"\nDropped {initial_rows - final_rows} rows with missing values.")
print("Shape of DataFrame after dropping missing values:", airquality.shape)
# Out:
# Dropped 0 rows with missing values.
# Shape of DataFrame after dropping missing values: (10000, 13)

# %%
# Check unique values in the 'pollutant' column to see if 'pm25' exists
print("Unique pollutants in the dataset:")
print(airquality['pollutant'].unique())
# Out:
# Unique pollutants in the dataset:
# ['bc' 'co']

# %% [markdown]
# Q3. Data Visualization
#
# 	1.	Create a histogram of the pm25 values.\\
#
# 	2.	Create a boxplot for the pm25 column.\\

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for 'bc' pollutant
bc_data = airquality[airquality['pollutant'] == 'bc']

if not bc_data.empty:
    # Create a histogram of the 'bc' values.
    plt.figure(figsize=(10, 6))
    sns.histplot(bc_data['value'], kde=True, bins=30)
    plt.title('Histogram of Black Carbon (bc) Values')
    plt.xlabel('bc Value')
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("No 'bc' data found in the dataset.")

# %% [markdown]
# ## Submitting Your Work
#
# Save you work to the path week07/week07_assignment_pandas.ipynb

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for 'co' pollutant
co_data = airquality[airquality['pollutant'] == 'co']

if not co_data.empty:
    # Create a boxplot for the 'co' column.
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=co_data['value'])
    plt.title('Boxplot of Carbon Monoxide (co) Values')
    plt.ylabel('co Value')
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("No 'co' data found in the dataset.")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for 'bc' pollutant (assuming bc_data is already defined from previous step)
# If bc_data is not defined, uncomment the line below:
# bc_data = airquality[airquality['pollutant'] == 'bc']

if not bc_data.empty:
    # Create a boxplot for the 'bc' column.
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=bc_data['value'])
    plt.title('Boxplot of Black Carbon (bc) Values')
    plt.ylabel('bc Value')
    plt.grid(axis='y', alpha=0.75)
    plt.show()
else:
    print("No 'bc' data found in the dataset.")
